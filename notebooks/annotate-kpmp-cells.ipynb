# %% [markdown]
# # Annotate KPMP data azimuth-annotate
#
# :warning: doesn't work

# %%
# !pip install cwltool cwlref-runner
# Out:
# Requirement already satisfied: cwltool in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (3.1.20240909164951)
# Requirement already satisfied: cwlref-runner in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (1.0)
# Requirement already satisfied: argcomplete in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (3.5.0)
# Requirement already satisfied: shellescape<3.9,>=3.4.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (3.8.1)
# Requirement already satisfied: spython>=0.3.0 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (0.3.14)
# Requirement already satisfied: mypy-extensions in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (1.0.0)
# Requirement already satisfied: psutil>=5.6.6 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (6.0.0)
# Requirement already satisfied: schema-salad<9,>=8.7 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (8.7.20240905150001)
# Requirement already satisfied: setuptools in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (59.6.0)
# Requirement already satisfied: rdflib<7.1.0,>=4.2.2 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (7.0.0)
# Requirement already satisfied: ruamel.yaml<0.19,>=0.16 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (0.18.6)
# Requirement already satisfied: pyparsing!=3.0.2 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (3.1.4)
# Requirement already satisfied: coloredlogs in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (15.0.1)
# Requirement already satisfied: prov==1.5.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (1.5.1)
# Requirement already satisfied: requests>=2.6.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (2.32.3)
# Requirement already satisfied: pydot<3,>=1.4.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (2.0.0)
# Requirement already satisfied: cwl-utils>=0.32 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwltool) (0.34)
# Requirement already satisfied: python-dateutil in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from prov==1.5.1->cwltool) (2.9.0.post0)
# Requirement already satisfied: networkx in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from prov==1.5.1->cwltool) (3.3)
# Requirement already satisfied: lxml in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from prov==1.5.1->cwltool) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from prov==1.5.1->cwltool) (1.16.0)
# Requirement already satisfied: cwl-upgrader>=1.2.3 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwl-utils>=0.32->cwltool) (1.2.11)
# Requirement already satisfied: packaging in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from cwl-utils>=0.32->cwltool) (24.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from rdflib<7.1.0,>=4.2.2->cwltool) (0.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from requests>=2.6.1->cwltool) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from requests>=2.6.1->cwltool) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from requests>=2.6.1->cwltool) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from requests>=2.6.1->cwltool) (2.2.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from ruamel.yaml<0.19,>=0.16->cwltool) (0.2.8)
# Requirement already satisfied: mistune<3.1,>=3 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from schema-salad<9,>=8.7->cwltool) (3.0.2)
# Requirement already satisfied: CacheControl[filecache]<0.15,>=0.13.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from schema-salad<9,>=8.7->cwltool) (0.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from coloredlogs->cwltool) (10.0)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from CacheControl[filecache]<0.15,>=0.13.1->schema-salad<9,>=8.7->cwltool) (1.1.0)
# Requirement already satisfied: filelock>=3.8.0 in /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages (from CacheControl[filecache]<0.15,>=0.13.1->schema-salad<9,>=8.7->cwltool) (3.16.1)

# %%
from cwltool.main import main as cwl_main
import tempfile
import json

def cwlrunner(workflow, job = {}, output_dir = "."):
    """
    Runs a CWL (Common Workflow Language) workflow using Singularity.

    Parameters:
    workflow (str): The path or URL to the CWL workflow file.
    job (dict, optional): A dictionary representing the job inputs. Defaults to an empty dictionary.

    Example:
    >>> cwlrunner('path/to/workflow.cwl', {'input1': 'value1', 'input2': 'value2'})
    """
    with tempfile.NamedTemporaryFile(mode="w+t", dir=".", suffix=".json") as job_file:
        job_file.write(json.dumps(job))
        job_file.flush()
        cwl_main(['--singularity', '--log-dir', output_dir, '--outdir', output_dir, workflow, job_file.name])

# %%
def download_azimuth_models():
    cwlrunner("https://raw.githubusercontent.com/hubmapconsortium/hra-workflows/main/containers/azimuth/download-data.cwl")

def download_popv_models():
    cwlrunner("https://raw.githubusercontent.com/hubmapconsortium/hra-workflows/main/containers/popv/download-data.cwl")

def run_hra_workflows(job, output_dir):
    cwlrunner("https://raw.githubusercontent.com/hubmapconsortium/hra-workflows/main/pipeline.cwl", job, output_dir)

def run_azimuth_annotate(h5ad, output_dir):
    cwlrunner("https://raw.githubusercontent.com/hubmapconsortium/azimuth-annotate/refs/heads/main/steps/azimuth-annotate.cwl", {
        "matrix": {
            "class": "File", "location": h5ad
        },
        "reference": "LK",
        "secondary_analysis_matrix": {
            "class": "File", "location": h5ad
        }
    }, output_dir)
    cwlrunner("https://raw.githubusercontent.com/hubmapconsortium/azimuth-annotate/refs/heads/main/steps/write-metadata.cwl", {
        "orig_secondary_analysis_matrix": {
            "class": "File", "location": h5ad
        },
        "secondary_analysis_matrix": {
            "class": "File", "location": output_dir + "/secondary_analysis.h5ad"
        },
        "version_metadata": {
            "class": "File", "location": output_dir + "/version_metadata.json"
        },
        "annotations_csv": {
            "class": "File", "location": output_dir + "/annotations.csv"
        }
    }, output_dir)


def run_azimuth_kidney(h5ad, output_dir):
    run_hra_workflows({
        "matrix": {
            "class": "File", "location": h5ad
        },
        "organ": "UBERON:0002113",
        "algorithms": [
            {
                "azimuth": {
                    "referenceDataDir": {
                        "class": "Directory",
                        "path": "models/azimuth"
                    },
                    "queryLayersKey": "raw"
                },
                "crosswalk": {
                    "table": {
                        "class": "File",
                        "path": "/home/bherr/workspaces/hubmap/hra-workflows-runner/crosswalking-tables/azimuth.csv"
                    },
                    "tableLabelColumn": "Annotation_Label",
                    "tableClidColumn": "CL_ID",
                    "tableMatchColumn": "CL_Match"
                },
                "summarize": {
                    "annotationMethod": "azimuth",
                    "cellSource": f"urn:h5ad:{h5ad}"
                },
                "directory": "azimuth"
            }
        ]
    }, output_dir)

def run_celltypist_kidney(h5ad, output_dir):
    run_hra_workflows({
        "matrix": {
            "class": "File", "location": h5ad
        },
        "organ": "UBERON:0002113",
        "algorithms": [
            {
                "celltypist": {
                    "queryLayersKey": "raw"
                },
                "crosswalk": {
                    "table": {
                    "class": "File",
                        "path": "/home/bherr/workspaces/hubmap/hra-workflows-runner/crosswalking-tables/celltypist.csv"
                    },
                    "tableLabelColumn": "Annotation_Label",
                    "tableClidColumn": "CL_ID",
                    "tableMatchColumn": "CL_Match"
                },
                "summarize": {
                    "annotationMethod": "celltypist",
                    "cellSource": f"urn:h5ad:{h5ad}"
                },
                "directory": "celltypist"
            }
        ]
    }, output_dir)

def run_popv_kidney(h5ad, output_dir):
    run_hra_workflows({
        "matrix": {
            "class": "File", "location": h5ad
        },
        "organ": "UBERON:0002113",
        "algorithms": [
            {
                "popv": {
                    "queryLayersKey": "raw",
                    "referenceDataDir": {
                        "class": "Directory",
                        "path": "models/popv/reference-data"
                    },
                    "modelsDir": {
                        "class": "Directory",
                        "path": "models/popv/models"
                    },
                },
                "crosswalk": {
                    "table": {
                    "class": "File",
                    "path": "/home/bherr/workspaces/hubmap/hra-workflows-runner/crosswalking-tables/popv.csv"
                    },
                    "tableLabelColumn": "Annotation_Label",
                    "tableClidColumn": "CL_ID",
                    "tableMatchColumn": "CL_Match"
                },
                "summarize": {
                    "annotationMethod": "popv",
                    "cellSource": f"urn:h5ad:{h5ad}"
                },
                "directory": "popv"
            }
        ]
    }, output_dir)

# %% [markdown]
# ## Run Azimuth

# %%
download_azimuth_models()

# %%
# !mkdir -p kpmp-sc-rnaseq

# %%
run_azimuth_annotate('kpmp-sc-rnaseq.h5ad', 'kpmp-sc-rnaseq')
# Out:
# INFO /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages/ipykernel_launcher.py 3.1.20240909164951
# INFO ['singularity', 'pull', '--force', '--name', 'hubmap_azimuth-annotate:1.5.sif', 'docker://hubmap/azimuth-annotate:1.5']
# INFO:    Using cached SIF image
# INFO [job azimuth-annotate.cwl] /tmp/ju6gact6$ singularity \
#     --quiet \
#     exec \
#     --contain \
#     --ipc \
#     --cleanenv \
#     --userns \
#     --home \
#     /tmp/ju6gact6:/sDuXXH \
#     --mount=type=bind,source=/tmp/ybyfbus_,target=/tmp \
#     --mount=type=bind,source=/home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/notebooks/kpmp-sc-rnaseq.h5ad,target=/var/lib/cwl/stg1d0b9513-87f5-41d9-862b-4871781aac59/kpmp-sc-rnaseq.h5ad,readonly \
#     --pwd \
#     /sDuXXH \
#     /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/notebooks/hubmap_azimuth-annotate:1.5.sif \
#     Rscript \
#     /azimuth_analysis.R \
#     LK \
#     /var/lib/cwl/stg1d0b9513-87f5-41d9-862b-4871781aac59/kpmp-sc-rnaseq.h5ad \
#     /var/lib/cwl/stg1d0b9513-87f5-41d9-862b-4871781aac59/kpmp-sc-rnaseq.h5ad
# WARNING [job azimuth-annotate.cwl] exited with status: 1
# ERROR [job azimuth-annotate.cwl] Job error:
# ("Error collecting output for parameter 'annotated_matrix': https://raw.githubusercontent.com/hubmapconsortium/azimuth-annotate/refs/heads/main/steps/azimuth-annotate.cwl:28:7: Did not find output file with glob pattern: ['secondary_analysis.h5ad'].", {})
# WARNING [job azimuth-annotate.cwl] completed permanentFail
# {}
# WARNING Final process status is permanentFail
# INFO /home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/.venv/lib/python3.10/site-packages/ipykernel_launcher.py 3.1.20240909164951
# ERROR Input object failed validation:
# tmpybn4vm2l.json:1:320: [Errno 2] No such file or directory:
#                         '/home/bherr/workspaces/hubmap/hra-hubmap-kpmp-integration/notebooks/kpmp-sc-rnaseq/annotations.csv'

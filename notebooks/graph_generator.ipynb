# %%
import scanpy as sc
import matplotlib.pyplot as plt
import pandas as pd

# %%
adata1 = sc.read_h5ad("hubmap-LK-processed.h5ad", backed="r")

# %%
gene_order = ['CCL21',  'SLC9A3','SPP1',"IL18","NBAS","SLC9A3","TIMP2","IGFBP7","SUGP1","MMP9","ITGAM","TFF3","B2M","S100A6","IL10",'IL6',"CXCL8","LCN2","HAVCR1","CST3","CCL2","FABP1"]
adata_ordered = adata1[:, adata1.var['hugo_symbol'].isin(gene_order)]

# %%
sc.pl.dotplot(adata_ordered, gene_order, groupby='predicted_label', gene_symbols='hugo_symbol', show=True)
plt.show()

# %%
adata2 = sc.read_h5ad("hubmap-RK-processed.h5ad", backed="r")

# %%
gene_order = ['CCL21',  'SLC9A3','SPP1',"IL18","NBAS","SLC9A3","TIMP2","IGFBP7","SUGP1","MMP9","ITGAM","TFF3","B2M","S100A6","IL10",'IL6',"CXCL8","LCN2","HAVCR1","CST3","CCL2","FABP1"]
adata_ordered2 = adata2[:, adata2.var['hugo_symbol'].isin(gene_order)]

# %%
sc.pl.dotplot(adata_ordered2, gene_order, groupby='predicted_label', gene_symbols='hugo_symbol', show=True)
plt.show()
